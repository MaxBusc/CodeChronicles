# %%
#Version 1, elle est éclatée mais elle fonctionne.

import random

print("Bonjour ! Jouons à pierre, feuille, ciseaux ensemble. Si tu gagnes, tu as le droit de rejouer ! Par contre, si c'est moi qui l'emporte, je prends le controle de ton ordinateur (:")
#Classique

choices = ["pierre","feuille","ciseaux"]
play_again_choices = ["oui","non"]
play_again = "oui"
#Pour un choix binaire, penser à faire plutôt à un boolean.

while play_again=="oui":
  user_choice = input ("C'est toi qui commence; que choisis tu ? ")
  #N'oublie pas, décompose étape par étape ton code. Commence toujours par définir tes variables pour pouvoir les utiliser simplement plus tard.
  while user_choice not in (choices):
    print ("ce n'est pas une option de jouer ça ! tu dois choisir entre pierre, feuille ou ciseaux.")
    #J'ai compris pourquoi print ("commentaire" ne fonctionnait pas ici ! Avant "2nd commentaire" il faut mettre input pour update la valeur, simplement demander de print et de recommencer ne le fais pas ! )
    user_choice = input ("Réessaye, que choisis tu ?")

  print (f"{user_choice} ? Intéressant, à moi de jouer maintenant !")
  print ("Je dis... "+(random.choice (choices))+" !")
  #ne surtout pas oublier le plus, sinon tu essayes de call le str avec la fonction et ça donne une erreur ! Je devrais également utiliser un f string.

  if user_choice == "pierre" and random.choice (choices) == "ciseaux" or user_choice == "feuille" and random.choice (choices) == "pierre" or user_choice == "ciseaux" and random.choice (choices) == "feuille"  :
#Ici, je re call random.choice 3 fois même si ça ne le print pas donc logique que ça bug derrière au niveau des résultats. Tu ne poeux pas utiliser une méthode (fonction) comme si c'était une variable.
    print ("Tu as gagné !")
  elif user_choice == random.choice (choices) :
    print ("Egalité !")
  else : print ("Tu as perdu !")


  play_again=input("Veux tu jouer à nouveau avec moi ? Tu peux me répondre en me disant oui ou non")

  while play_again not in (play_again_choices):
    play_again = input("Réponds par oui ou non s'il te plait")

else :
  print("Merci d'avoir joué avec moi, A la prochaine fois!")
# Out:
# Bonjour ! Jouons à pierre, feuille, ciseaux ensemble. Si tu gagnes, tu as le droit de rejouer ! Par contre, si c'est moi qui l'emporte, je prends le controle de ton ordinateur (:
# C'est toi qui commence; que choisis tu ? oui
# ce n'est pas une option de jouer ça ! tu dois choisir entre pierre, feuille ou ciseaux.
# Réessaye, que choisis tu ?pierre
# pierre ? Intéressant, à moi de jouer maintenant !
# Je dis... ciseaux !
# Tu as perdu !
# Veux tu jouer à nouveau avec moi ? Tu peux me répondre en me disant oui ou nonj
# Réponds par oui ou non s'il te plaitgf
# Réponds par oui ou non s'il te plaitnon
# Merci d'avoir joué avec moi, A la prochaine fois!

# %%
#Version 2, c'est déjà plus propre !!! Codons un jeu de Pierre-Feuille-Ciseaux .


#Nous utiliserons seulement le randint, pas besoin de toute la bibliothèque
from random import randint

#On définit les variables qui seront utilisés par toutes les fonctio2ns par la suite
possible_choices = {1:"stone",2:"paper",3:"scissors"}
#Mieux vaudrait insérer ça dans chaque fonction plutôt que d'en faire une
#variable globale, ça pose des problèmes plus tard et cela empêche que les
#variables fonctionnent de manières indépendantes si on les exportent.

#On commence par créer la fonction codant le tour du joueur
def create_player_turn():
  user_choice = int(input("Choose 1 for stone, 2 for paper or 3 for scissors."))

  #On vérifie que le choix et valide
  while user_choice not in possible_choices :
    user_choice = int(input("You can only choose 1, 2 or 3"))
    #Ajouter l'int ici est inutile, et fait même cracher le code si l'utilisateur rentre autre chose que 1, 2 ou 3 !
    print(f"You chose {user_choice}? Interesting. My turn now.")
     #Comprends tu pourquoi ç'est (f"I chose {possible_choices[computer_choice]}.") et pas f{user_choice}?
    return user_choice
# return 'variable défini en local' retourne simplement la valeur de la variable (user_choice ici), pas la variable en elle même. Celle ci reste seulement accessible en local.
#Tu dois assigner la valeur retournée par user_choice à la fonction créee !!! Comme tu le fais dans cette ligne suivante
user_choice=create_player_turn()

#Ensuite, on code le tour de l'ordinateur
def create_computer_turn():
  computer_choice = randint(1, 3)
  print(f"I chose {possible_choices[computer_choice]}.")
  #Comprends tu pourquoi ç'est (f"I chose {possible_choices[computer_choice]}.") et pas f{computer_choice_choice}?
  return computer_choice
# return 'variable défini en local' retourne simplement la valeur de la variable (computer_choice ici), pas la variable en elle même. Celle ci reste seulement accessible en local.
#Tu dois assigner la valeur retournée par user_choice à la fonction créee !!! Comme tu le fais dans cette ligne suivante
computer_choice=create_computer_turn()

#Ensuite, on code comment le résultat est déterminé
def get_result(user_choice,computer_choice):
  #On a besoin de ces 2 arguments, vu qu'on les utilisent dans la fonction et qu'ils viennent d'être créés par les 2 fonctions précédentes return par l'update.
  if(
      user_choice==1 and computer_choice==3
      or user_choice==2 and computer_choice==1
      or user_choice==3 and computer_choice==2
  ):
    print("You Win !")
  elif(
      user_choice==1 and computer_choice==1
      or user_choice==2 and computer_choice==2
      or user_choice==3 and computer_choice==3
      #Ici, mieux vaut utiliser user_choice==computer_choice !
  ):
      print("It's a Tie !")
  else:print("You Lost !")
  # pas besoin de return get_result, comprends tu pourquoi ?

  #Ensuite, On code la possibilité de recommencer à jouer.

def play_again():
  replay=input ("Do you want to play again ? (yes or no)")
  if replay == "yes":
    play_game()
  if replay != "yes":
    print("Thanks for playing!")


#Pour finir, on regroupe notre code dans une fonction qui sera notre jeu !
def play_game():
  user_choice=create_player_turn()
  computer_choice=create_computer_turn()
  get_result(user_choice,computer_choice)
  play_again()

#Essayons maintenant de tenir à jour un score des victoires/défaites. Pour cela nous commençons

#Fonction à améliorer, gérer les cas de majuscules avec replay.lower mais aussi en supprimant le elif et garder juste if/else
def play_again():
  replay=input ("Do you want to play again ? (yes or no)")
  while replay not in "yes" or "no":
    replay=input("Answer by yes or no please")
    if replay == "yes":
      play_game()
    elif replay == "no":
      print("Thanks for playing!")

def update_score():
  computer_score=""
  user_score=""
if user win:, user_score=user_score+1
elif computer win:computer_score=computer_score+1

play_game()
# Out:
# Choose 1 for stone, 2 for paper or 3 for scissors.2
# I chose scissors.
# You Lost !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-6c2b35f11b42> in <cell line: 68>()
#      66   play_again()
#      67
# ---> 68 play_game()
#      69
#      70
#
# <ipython-input-97-6c2b35f11b42> in play_game()
#      64   computer_choice=create_computer_turn()
#      65   get_result(user_choice,computer_choice)
# ---> 66   play_again()
#      67
#      68 play_game()
#
# <ipython-input-97-6c2b35f11b42> in play_again()
#      52
#      53 def play_again():
# ---> 54   replay=input ("Do you want to play again ? (yes or no)")
#      55   if replay == "yes":
#      56     play_game()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
# ...

# %%
#3ème version, ce coup ci avec l'idée de Yann
from random import randint

choices={1:"stone",2:"paper",3:"scissors"}

player_choice=int(input(f"Chooose between{choices}"))

computer_choice=randint(0, len(choices) - 1)
#Indexation d'une liste commence toujours de 0 jusqu'à -1 puisqu'il exlut
#Sa Borne extérieure. Logique, sinon le random accederait à la valeur 4 ici qui n'existe pas
#autre méthode, utiliser list.index !

print(f"Je choisis{computer_choice}")

if player_choice==computer_choice:
  print("égalité)")
elif computer_choice < player_choice or player_choice > computer_choice and player_choice==0 and computer_choice==2:
  print("tu gagnes")
else: print ("Tu perds")

def update_score():
  computer_score=""
  user_score=""
if user win:, user_score=user_score+1
elif computer win:computer_score=computer_score+1
# Out:
# Chooose between{1: 'stone', 2: 'paper', 3: 'scissors'}1
# Je choisis1
# égalité)

# %%
#4ème Version, version définitive ? CEST FAUX CEST ENCORE TELLEMENT LE BORDEL

#Nous utiliserons seulement le randint, pas besoin de toute la bibliothèque
from random import randint

#On commence par créer la fonction codant le tour du joueur
def create_player_turn():
  possible_choices = {1:"stone",2:"paper",3:"scissors"}
  try:
    user_choice = int(input("Choose 1 for stone, 2 for paper or 3 for scissors."))
  except ValueError:
    print ("It looks like this wasn't a valid number, try again please")
#On vérifie que le choix et valide
  while user_choice not in possible_choices :
    try:
      user_choice = int(input("You can only choose 1, 2 or 3"))
    except ValueError:
      print ("It looks like this wasn't a valid number, try again please")
  print(f"You chose {possible_choices[user_choice]}? Interesting. My turn now.")
  return user_choice
user_choice=create_player_turn()


#Ensuite, on crée la fonction codant le tour de l'ordinateur
def create_computer_turn():
  possible_choices = {1:"stone",2:"paper",3:"scissors"}
  computer_choice = randint(1, 3)
  print(f"I choose {possible_choices[computer_choice]}.")
  return computer_choice
computer_choice=create_computer_turn()

#On créee une fonction définissant les conditions pour que l'Humain gagne
def user_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==3
  or user_choice==2 and computer_choice==1
  or user_choice==3 and computer_choice==2
)
#On créee une fonction définissant les conditions d'une égalité
def draw(user_choice,computer_choice):(
    user_choice==1 and computer_choice==1
    or user_choice==2 and computer_choice==2
    or user_choice==3 and computer_choice==3
    )
#On créee une fonction définissant les conditions pour que l'ordinateur gagne
def computer_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==2
  or user_choice==2 and computer_choice==3
  or user_choice==3 and computer_choice==1
)


#POURQUOI créer cette variable intermédiaire, turn result ? Inutile pour le moment, complexifie ton code
def get_result():
  turn_result = user_win(user_choice,computer_choice) or draw(user_choice,computer_choice) or computer_win(user_choice,computer_choice)
  if turn_result == user_win(user_choice,computer_choice):
    print("1 points for you")
  elif turn_result == draw(user_choice,computer_choice):
    print("Nobody Wins")
  else:print("1 points for me !")
  return turn_result
turn_result=get_result()

   #Ensuite, On code la possibilité de recommencer à jouer.


def play_again():
  replay = input("Do you want to play again? (yes or no)")
  while replay.lower() not in ["yes", "no"]:
    replay = input("Answer by yes or no please")

  if replay.lower() == "yes":
    play_game()
  else:
    print("Thanks for playing!")



#Pour finir, on regroupe notre code dans une fonction qui sera notre jeu !
def play_game():
  user_choice=create_player_turn()
  computer_choice=create_computer_turn()
  get_result()
  play_again()

#Essayons maintenant de tenir à jour un score des victoires/défaites. Pour cela nous commençons



play_game()
# Out:
#   File "<ipython-input-46-f223d112641f>", line 11
#     break
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
def create_player_turn():
  possible_choices = {1:"stone",2:"paper",3:"scissors"}
  while True:
    try:
      user_choice = int(input("Choose 1 for stone, 2 for paper or 3 for scissors."))
      if user_choice not in range (1,4):
        user_choice =int(input("Remember, 1 is for stone, 2 is for paper and 3 is for scissors. You can't choose another number."))
      else:
         break
    except ValueError:
      print ("It looks like this wasn't a valid number, try again please")

  print(f"You chose {possible_choices[user_choice]}? Interesting. My turn now.")
  return user_choice
user_choice=create_player_turn()

#Ensuite, on crée la fonction codant le tour de l'ordinateur
def create_computer_turn():
  possible_choices = {1:"stone",2:"paper",3:"scissors"}
  computer_choice = randint(1, 3)
  print(f"I choose {possible_choices[computer_choice]}.")
  return computer_choice
computer_choice=create_computer_turn()

#On créee une fonction définissant les conditions pour que l'Humain gagne
def user_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==3
  or user_choice==2 and computer_choice==1
  or user_choice==3 and computer_choice==2
)
#On créee une fonction définissant les conditions d'une égalité
def draw(user_choice,computer_choice):(
    user_choice==1 and computer_choice==1
    or user_choice==2 and computer_choice==2
    or user_choice==3 and computer_choice==3
    )
#On créee une fonction définissant les conditions pour que l'ordinateur gagne
def computer_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==2
  or user_choice==2 and computer_choice==3
  or user_choice==3 and computer_choice==1
)


def get_result():
  turn_result = user_win(user_choice,computer_choice) or draw(user_choice,computer_choice) or computer_win(user_choice,computer_choice)
  if turn_result == user_win(user_choice,computer_choice):
    print("1 points for you")
    turn_result = user_win (user_choice,computer_choice)
  elif turn_result == draw(user_choice,computer_choice):
    print("Nobody Wins")
    turn_result = draw(user_choice,computer_choice)
  else:
    print("1 points for me !")
    turn_result = computer_win(user_choice,computer_choice)
  return turn_result
turn_result=get_result()
#Il est bien mon pierre feuilel ciseaux, tu gagnes quoi qu'il arrive.
# Out:
# Choose 1 for stone, 2 for paper or 3 for scissors.1
# You chose stone? Interesting. My turn now.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee15d691b4ea> in <cell line: 23>()
#      21   print(f"I choose {possible_choices[computer_choice]}.")
#      22   return computer_choice
# ---> 23 computer_choice=create_computer_turn()
#      24
#      25 #On créee une fonction définissant les conditions pour que l'Humain gagne
#
# <ipython-input-2-ee15d691b4ea> in create_computer_turn()
#      18 def create_computer_turn():
#      19   possible_choices = {1:"stone",2:"paper",3:"scissors"}
# ---> 20   computer_choice = randint(1, 3)
#      21   print(f"I choose {possible_choices[computer_choice]}.")
#      22   return computer_choice
#
# NameError: name 'randint' is not defined

# %%
#On créee une fonction définissant les conditions pour que l'Humain gagne
def user_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==3
  or user_choice==2 and computer_choice==1
  or user_choice==3 and computer_choice==2
)
#On créee une fonction définissant les conditions d'une égalité
def draw(user_choice,computer_choice):(
    user_choice==1 and computer_choice==1
    or user_choice==2 and computer_choice==2
    or user_choice==3 and computer_choice==3
    )
#On créee une fonction définissant les conditions pour que l'ordinateur gagne
def computer_win(user_choice,computer_choice):(
  user_choice==1 and computer_choice==2
  or user_choice==2 and computer_choice==3
  or user_choice==3 and computer_choice==1
)

def get_result():
  turn_result = user_win(user_choice,computer_choice) or draw(user_choice,computer_choice) or computer_win(user_choice,computer_choice)
  if turn_result == user_win(user_choice,computer_choice):
    print("1 points for you")
  elif turn_result == draw(user_choice,computer_choice):
    print("Nobody Wins")
  else:print("1 points for me !")
  return turn_result
turn_result=get_result()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-34bd275f454d> in <cell line: 28>()
#      26   else:print("1 points for me !")
#      27   return turn_result
# ---> 28 turn_result=get_result()
#
# <ipython-input-1-34bd275f454d> in get_result()
#      19
#      20 def get_result():
# ---> 21   turn_result = user_win(user_choice,computer_choice) or draw(user_choice,computer_choice) or computer_win(user_choice,computer_choice)
#      22   if turn_result == user_win(user_choice,computer_choice):
#      23     print("1 points for you")
#
# NameError: name 'user_choice' is not defined
