# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
names = ["Fredy", "Nicolas", "Alexandre"]

for i in enumerate(names):
  print(i)

print(type(names))
# Out:
# (0, 'Fredy')
# (1, 'Nicolas')
# (2, 'Alexandre')
# <class 'list'>

# %% [markdown]
# 1. What type of object is returned as output?
# Hint: You can use `type(i)`.

# %% [markdown]
# Answer:
# As output, a list is returned

# %%
for i, val in enumerate(names):
  print(val)

print(type(i))
print(type(val))
# Out:
# Fredy
# Nicolas
# Alexandre
# <class 'int'>
# <class 'str'>

# %% [markdown]
# 2. What does `i` correspond to?
# What does `val` correspond to?
# Why is it so?

# %% [markdown]
# Answer: i correspond to an integer, he is the iterable. of this loop.
# val correspond to a string, it is the value we want to find and the purpose of creating this loop.
#
# i is an integer because it need to be one in order to iterate trough names, the loop wouldn't work otherwise. val is a str because we are looking to a specific value in 'names', so those values must be str.

# %%
for val, i in enumerate(names):
  print(val)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 3. This time, `i` returns first names and `val` returns numbers. Why is it so?

# %% [markdown]
# The situation is reversed compared to the last loop, now var val correspond to an integer, he is the iterable of this loop.
# i correspond to a string, it is the value we want to find and the purpose of creating this loop.
#
# val is an integer because it need to be one in order to iterate trough names, the loop wouldn't work otherwise. i is a str because we are looking to a specific value in 'names', so those values must be str.

# %% [markdown]
# 4. What does the built in function `enumerate` do?
# In what cases can it be useful?

# %% [markdown]
# Answer:
# https://www.w3schools.com/python/ref_func_enumerate.asp
#
# La fonction enumerate ajoute un compteur à un objet itérable. Elle retourne un objet enumerate qui peut être utilisé pour énumérer les éléments d'une séquence et leur attribuer un index.
#
# La syntaxe de la fonction Enumerate est la suivante :
#
# enumerate(sequence, start=0)
#
# Où sequence est l'objet à énumérer et start est l'indice à partir duquel commencer la numérotation (par défaut, 0).
#
# Pour utiliser la fonction enumerate, on doit d'abord définir une séquence à énumérer. Cela peut être une liste, un tuple, une chaîne de caractères, un dictionnaire ou tout autre objet itérable.
#
# Elle est utile pour la création d'un dictionnaire, simplifier le code et le rendre plus lisible.

# %% [markdown]
# # Mission 2

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list[8] = "Marshall"

test_list
# Out:
# ['Hi', 'my', 'name', 'is', 'hi', 'my', 'name', 'is', 'Marshall']

# %% [markdown]
# 1. What does the 8 in square brackets mean?
# What action has been performed?

# %% [markdown]
# Answer: It means the 8th index in the list between before the brackets (rememebr that we start at 0, so it's actually the 9th element).
# In this case, 'chyckychycky has been replaced by 'Marshall'.

# %%
for i in range(4):
  print(test_list[i])
# Out:
# Hi
# my
# name
# is

# %% [markdown]
# 2. What does `range(4)` mean?
# Why are only the first 4 elements of `test_list` displayed?

# %% [markdown]
# Answer: The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number.
# The Syntax is range(start, stop, step)
#
# Here range(4) therefore call the objects from index 0 to index 3 of whatever str/list/tuple/dictionnary/set we'll use after. THat's why here only the first 4 elements of test_list are displayed.

# %%
for i in range(2, 8, 2):
  print(test_list[i])
# Out:
# name
# hi
# name

# %% [markdown]
# 3. What does `range(2,8,2)` mean ?
# Why are only the elements 'name', 'hi' and 'name' displayed?

# %% [markdown]
# Answer:
# it means to select all elements from index 2 to 8, with a step of 2.
#
# in the (test_list[i]), name is at index[2], hi at index[4] and name at index[6]. Index[8] is excluded.

# %% [markdown]
# # Mission 3

# %%
numbers = [2,3,1,5,9]

for i in range(10,15):
  numbers.append(i)

numbers
# Out:
# [2, 3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 1. What does `range(10,15)` mean ?
#   What is the purpose of the method `append()` ?

# %% [markdown]
# Answer:

# %%
It means to select all elements from index 10 to 15(excluded), with a step of 1.
Appends add the object between the () at the end of the list written before the.append()

# %% [markdown]
# 2. What is the purpose of the `del` command?

# %% [markdown]
# Answer: The del keyword is used to delete objects. In Python everything is an object, so the del keyword can also be used to delete variables, lists, or parts of a list

# %% [markdown]
# # Mission 4

# %%
import random

random.randint(0,10)
# Out:
# 5

# %% [markdown]
# 1. What can the method `randint()` do ?

# %% [markdown]
# Answer: It chooses a random int betwen the slicing we give between the () randit(2,6) chooses a random int between 2 and 6 included.

# %% [markdown]
# 2. What can the method `.insert()` do ?
# You must answer using the terms 'parameter' and 'argument'.

# %% [markdown]
# Answer:
# The insert() method inserts the specified value at the specified position.
# To be more precise, it inserts an element into a list at a specified index.
# The index and the element are passed as arguments.
# When the method is defined, the variables that it accepts are called parameters.
#
# Another way to explain it is that
# When you create your own method, the variables you define for it are called formal parameters. When you call the method to do its job, you give or pass in arguments or actual parameters to it that are then saved in the parameter variables

# %% [markdown]
# # Mission 5

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]
print(type(test_list))
test_list = " ".join(test_list)
print(type(test_list))

test_list
# Out:
# <class 'list'>
# <class 'str'>
# 'Hi my name is hi my name is chickychicky'

# %% [markdown]
# 1. What can the `.join()` method do?
# What is the type of `test_list` before using `.join()`?
# What is the type of `test_list` after using `.join()`?

# %% [markdown]
# Answer:
# The .join() method takes a list of strings and concatenates them into a single string, separated by the string that the method is called on.
#
# test_list is of type list before using .join().
# test_list is of type str after using .join().

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"
print(type(christmas))
christmas.split()
print(type(christmas.split()))
print(christmas)
# Out:
# <class 'str'>
# <class 'list'>
# <built-in method split of str object at 0x788406446ce0>

# %% [markdown]
# 2. What can the `.split()` method do?
# What is the type of `christmas` before using `.split()`?
# What is the type of `christmas` after using `.split()`?

# %% [markdown]
# Answer:
# The .split() method can split a string into a list of substrings based on a delimiter. If no delimiter is specified, it defaults to splitting on whitespace.
#
# christmas is of type string before using .split().
# christmas is of type list after using .split().

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fait à chaque fois. C'est la vie"


christmas.split("à")
# Out:
# ["Noël c'est bien, mais attention ",
#  ' ne pas manger trop de chocolat. On le sait, mais on le fait ',
#  " chaque fois. C'est la vie"]

# %% [markdown]
# 3. Why does the `.split()` method split the `string` into 3 elements?

# %% [markdown]
# Answer: Because it splits the string wherever there is a 'à', which happens 2 times in this string, therefore separating the string in three.
# 'à' is the delimiter
